# %% [markdown]
# <a href="https://colab.research.google.com/github/susan291-gifs/SussieAssignment/blob/main/Susan_PaperFoldedProblem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1

# %%
# Code to calculate the thickness when the paper is folded once

THICKNESS = 0.00008

folded_thickness = THICKNESS * 2**43

print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %% [markdown]
# Problem 2

# %%
# Convert meters to kilometers and display with two decimal places
print("Thickness: {: .2f} kilometers".format(folded_thickness / 1000))
# Out:
# Thickness:  703687.44 kilometers

# %% [markdown]
# Problem 3

# %%
folded_thickness1 = THICKNESS
for i in range(1, 10):
  folded_thickness1 *= 2
  print("Thickness: {} meters".format(folded_thickness1))
# Out:
# Thickness: 2e-05 meters
# Thickness: 4e-05 meters
# Thickness: 8e-05 meters
# Thickness: 0.00016 meters
# Thickness: 0.00032 meters
# Thickness: 0.00064 meters
# Thickness: 0.00128 meters
# Thickness: 0.00256 meters
# Thickness: 0.00512 meters

# %% [markdown]
# Problem 4

# %%
import time
start = time.time()
#####
# Paste the code you want to compare here
folded_thickness1 = THICKNESS
for i in range(1, 10):
  folded_thickness1 *= 2
  print("Thickness: {} meters".format(folded_thickness1))
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# Thickness: 2e-05 meters
# Thickness: 4e-05 meters
# Thickness: 8e-05 meters
# Thickness: 0.00016 meters
# Thickness: 0.00032 meters
# Thickness: 0.00064 meters
# Thickness: 0.00128 meters
# Thickness: 0.00256 meters
# Thickness: 0.00512 meters
# time : 0.0015265941619873047[s]

# %% [markdown]
# Problem 4

# %%
# %%timeit
#####
# Paste the code you want to compare here
folded_thickness1 = THICKNESS
for i in range(1, 10):
  folded_thickness1 *= 2
  print("Thickness: {} meters".format(folded_thickness1))
#####
# Out:
# Streaming output truncated to the last 5000 lines.
# Thickness: 0.00064 meters
# Thickness: 0.00128 meters
# Thickness: 0.00256 meters
# Thickness: 0.00512 meters
# Thickness: 2e-05 meters
# Thickness: 4e-05 meters
# Thickness: 8e-05 meters
# Thickness: 0.00016 meters
# Thickness: 0.00032 meters
# Thickness: 0.00064 meters
# Thickness: 0.00128 meters
# Thickness: 0.00256 meters
# Thickness: 0.00512 meters
# Thickness: 2e-05 meters
# Thickness: 4e-05 meters
# Thickness: 8e-05 meters
# Thickness: 0.00016 meters
# Thickness: 0.00032 meters
# Thickness: 0.00064 meters
# Thickness: 0.00128 meters
# Thickness: 0.00256 meters
# Thickness: 0.00512 meters
# Thickness: 2e-05 meters
# Thickness: 4e-05 meters
# Thickness: 8e-05 meters
# Thickness: 0.00016 meters
# Thickness: 0.00032 meters
# Thickness: 0.00064 meters
# Thickness: 0.00128 meters
# Thickness: 0.00256 meters
# Thickness: 0.00512 meters
# Thickness: 2e-05 meters
# Thickness: 4e-05 meters
# Thickness: 8e-05 meters
# ...

# %% [markdown]
# Problem 5

# %%
folded_thickness_list = []
folded_thickness1 = THICKNESS
for i in range(1, 10):
  folded_thickness1 *= 2
  folded_thickness_list.append(folded_thickness1)

# %% [markdown]
# Problem 6

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Display the graph. Title and axis label name.
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness_list)  # Enter the variable name of the list in "List name"
plt.show()

# %% [markdown]
# Problem 7

# %%
# Display a red line graph.
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness_list, color='red')
plt.show()
